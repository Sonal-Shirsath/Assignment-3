# %%
list=[1,2,3,4,5]
list1=["a","b","c","d","e"]
op={}
for key in list :
    for value in list1:
        op[key]=value
        break
print(op)
# Out:
# {1: 'a', 2: 'a', 3: 'a', 4: 'a', 5: 'a'}

# %%
file=open(r'C:\Users\ldell\File.txt') 
text=file.read() 
file1=open(r'C:\Users\dell\file1.txt') 
text1=file1.read() 
text=text+"\n" 
text=text+text1 
file2=open(r'C:\Users\dell\file2.txt','w') 
file2.write(text1)
